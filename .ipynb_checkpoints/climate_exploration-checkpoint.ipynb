# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt
from datetime import timedelta, date

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, desc

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %% [markdown]
# # Explore Database

# %%
# use inspector to get table names and columns
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
# Inspect the tables - measurement
inspector = inspect(engine)

measurement_col = inspector.get_columns('measurement')
for col in measurement_col:
    print(col["name"], col["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Inspect the tables - station

station_col = inspector.get_columns('station')

for col in station_col:
    print(col["name"], col["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
#design a query to find out the last percept entry, want to pull all the date and see the structure of the data
engine.execute("SELECT * FROM measurement LIMIT 10").fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0)]

# %%
#find out how many entries in all
len(engine.execute("SELECT * FROM measurement").fetchall())
# Out:
# 19550

# %%
#determine the max entry in the table - 2017-08-23
result = session.query(Measurement, func.max(Measurement.date)).all()
result
for i,date in result:
    print(date)
# Out:
# 2017-08-23

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results:between 2016-08-23 to 2017-08-23
perc_over_year = session.query(Measurement.date, Measurement.prcp).\
    filter(Measurement.date.between ("2016-08-23", "2017-08-23"))
perc_over_year

for data in perc_over_year:
    print(data)
# Out:
# ('2016-08-23', 0.0)
# ('2016-08-24', 0.08)
# ('2016-08-25', 0.08)
# ('2016-08-26', 0.0)
# ('2016-08-27', 0.0)
# ('2016-08-28', 0.01)
# ('2016-08-29', 0.0)
# ('2016-08-30', 0.0)
# ('2016-08-31', 0.13)
# ('2016-09-01', 0.0)
# ('2016-09-02', 0.0)
# ('2016-09-03', 0.0)
# ('2016-09-04', 0.03)
# ('2016-09-05', None)
# ('2016-09-06', None)
# ('2016-09-07', 0.05)
# ('2016-09-08', 0.0)
# ('2016-09-09', 0.03)
# ('2016-09-10', 0.0)
# ('2016-09-11', 0.05)
# ('2016-09-12', 0.0)
# ('2016-09-13', 0.02)
# ('2016-09-14', 1.32)
# ('2016-09-15', 0.42)
# ('2016-09-16', 0.06)
# ('2016-09-17', 0.05)
# ('2016-09-18', 0.0)
# ('2016-09-19', 0.0)
# ('2016-09-20', 0.0)
# ('2016-09-21', 0.0)
# ('2016-09-22', 0.02)
# ('2016-09-23', 0.0)
# ('2016-09-24', 0.0)
# ('2016-09-25', 0.0)
# ('2016-09-26', 0.06)
# ('2016-09-27', 0.02)
# ('2016-09-28', 0.0)
# ('2016-09-29', 0.0)
# ('2016-09-30', 0.0)
# ('2016-10-01', 0.0)
# ('2016-10-02', 0.0)
# ('2016-10-03', 0.0)
# ('2016-10-04', 0.0)
# ('2016-10-05', 0.0)
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
perc_df = pd.DataFrame(perc_over_year, columns=["Date", "Percipitation"])
perc_df.set_index('Date', inplace=True)

# Sort the dataframe by date
perc_df = perc_df.sort_index()
perc_df
# Out:
#             Percipitation
# Date
# 2016-08-23           0.00
# 2016-08-23            NaN
# 2016-08-23           1.79
# 2016-08-23           0.05
# 2016-08-23           0.15
# 2016-08-23           0.70
# 2016-08-23           0.02
# 2016-08-24           0.08
# 2016-08-24           2.15
# 2016-08-24           2.28
# 2016-08-24            NaN
# 2016-08-24           1.45
# 2016-08-24           1.22
# 2016-08-24           2.15
# 2016-08-25           0.08
# 2016-08-25           0.00
# 2016-08-25           0.21
# 2016-08-25           0.06
# 2016-08-25           0.00
# 2016-08-25           0.11
# 2016-08-25           0.08
# 2016-08-26           0.03
# 2016-08-26           0.01
# 2016-08-26           0.00
# 2016-08-26           0.04
# 2016-08-26           0.02
# 2016-08-26           0.00
# 2016-08-27           0.18
# 2016-08-27           0.12
# 2016-08-27           0.00
# ...                   ...
# 2017-08-16           0.42
# 2017-08-16           0.12
# 2017-08-16           0.07
# ...

# %%
#plot the data frame

perc_df.plot()
plt.tight_layout()

plt.xticks(color= "white")
plt.show()
plt.close()

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
pd.DataFrame(perc_df["Percipitation"].describe())
# Out:
#        Percipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?
quantity_of_stations = session.query(Measurement.station).distinct().all()
num_stations=len(quantity_of_stations)
num_stations
print(f'There are {num_stations} stations available in this dataset.')
# Out:
# There are 9 stations available in this dataset.

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
active_station = session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station).\
    order_by(func.count(Measurement.station).desc()).all()
    
active_station
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature from the most active station?
most_active_stats = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.station == "USC00519281").all()
print(most_active_stats)
print('For the most active station in the data set: USC00519281:')
print('the lowest temperature recorded is: 54.0 *F,')
print('the highest temperature recorded is: 85.0 *F,')
print('the highest temperature recorded is: 71.66 *F.')
# Out:
# [(54.0, 85.0, 71.66378066378067)]
# For the most active station in the data set: USC00519281:
# the lowest temperature recorded is: 54.0 *F,
# the highest temperature recorded is: 85.0 *F,
# the highest temperature recorded is: 71.66 *F.

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

tobs = session.query(Measurement.date, Measurement.tobs).\
    filter(Measurement.date.between ("2016-08-23", "2017-08-23")).\
    filter(Measurement.station == "USC00519281").all()

tobs
# Out:
# [('2016-08-23', 77.0),
#  ('2016-08-24', 77.0),
#  ('2016-08-25', 80.0),
#  ('2016-08-26', 80.0),
#  ('2016-08-27', 75.0),
#  ('2016-08-28', 73.0),
#  ('2016-08-29', 78.0),
#  ('2016-08-30', 77.0),
#  ('2016-08-31', 78.0),
#  ('2016-09-01', 80.0),
#  ('2016-09-02', 80.0),
#  ('2016-09-03', 78.0),
#  ('2016-09-04', 78.0),
#  ('2016-09-05', 78.0),
#  ('2016-09-06', 73.0),
#  ('2016-09-07', 74.0),
#  ('2016-09-08', 80.0),
#  ('2016-09-09', 79.0),
#  ('2016-09-10', 77.0),
#  ('2016-09-11', 80.0),
#  ('2016-09-12', 76.0),
#  ('2016-09-13', 79.0),
#  ('2016-09-14', 75.0),
#  ('2016-09-15', 79.0),
#  ('2016-09-16', 78.0),
#  ('2016-09-17', 79.0),
#  ('2016-09-18', 78.0),
#  ('2016-09-19', 78.0),
#  ('2016-09-20', 76.0),
#  ('2016-09-21', 74.0),
#  ('2016-09-22', 77.0),
#  ('2016-09-23', 78.0),
#  ('2016-09-24', 79.0),
#  ('2016-09-25', 79.0),
#  ('2016-09-26', 77.0),
#  ('2016-09-27', 80.0),
#  ('2016-09-28', 78.0),
#  ('2016-09-29', 78.0),
#  ('2016-09-30', 78.0),
#  ('2016-10-01', 77.0),
# ...

# %%
tobs_df=pd.DataFrame(tobs, columns=["Date", "Temperature"])
tobs_df
# Out:
#            Date  Temperature
# 0    2016-08-23         77.0
# 1    2016-08-24         77.0
# 2    2016-08-25         80.0
# 3    2016-08-26         80.0
# 4    2016-08-27         75.0
# 5    2016-08-28         73.0
# 6    2016-08-29         78.0
# 7    2016-08-30         77.0
# 8    2016-08-31         78.0
# 9    2016-09-01         80.0
# 10   2016-09-02         80.0
# 11   2016-09-03         78.0
# 12   2016-09-04         78.0
# 13   2016-09-05         78.0
# 14   2016-09-06         73.0
# 15   2016-09-07         74.0
# 16   2016-09-08         80.0
# 17   2016-09-09         79.0
# 18   2016-09-10         77.0
# 19   2016-09-11         80.0
# 20   2016-09-12         76.0
# 21   2016-09-13         79.0
# 22   2016-09-14         75.0
# 23   2016-09-15         79.0
# 24   2016-09-16         78.0
# 25   2016-09-17         79.0
# 26   2016-09-18         78.0
# 27   2016-09-19         78.0
# 28   2016-09-20         76.0
# 29   2016-09-21         74.0
# ..          ...          ...
# ...

# %%
x = tobs_df["Temperature"]
plt.figure(figsize=(15,10))
plt.hist(x, bins=12)

plt.ylabel("Frequency of Temp. Observations", size = 15)
plt.title("Frequency of Temperature Observations at USC00519281")
plt.show()
plt.close()

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
print(calc_temps('2016-08-23', '2017-08-23'))
# Out:
# [(58.0, 74.59058295964125, 87.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
avg_temp = 74.59
yerr = (87.0-58)/2
x = ""
plt.figure(figsize=(4,7))
plt.ylim(0, 100)
plt.bar(x, avg_temp, yerr=yerr, color='r', alpha=0.5)
plt.tight_layout()
plt.ylabel("Temperature (F)", size = 15)
plt.title("Trip Avg. Temp: Aug 23, 2016 to Aug 23, 2017")

plt.show()
plt.close()

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
def rainfall(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        Station, sum of prcp, latitude of station, longitude of station, station elevation
    """
    
    return session.query(Measurement.station, func.sum(Measurement.prcp), Station.latitude, Station.longitude, Station.elevation).\
        select_from(Measurement).\
        join(Station, Measurement.station==Station.station).\
        filter(Measurement.date >= start_date).\
        filter(Measurement.date <= end_date).\
        group_by((Measurement.station)).\
        order_by(func.sum(Measurement.tobs).desc()).all()

# %%
print(rainfall('2016-08-23', '2017-08-23'))
# Out:
# [('USC00519397', 16.089999999999986, 21.2716, -157.8168, 3.0), ('USC00519523', 38.01, 21.33556, -157.71139, 19.5), ('USC00519281', 70.03000000000003, 21.45167, -157.84888999999998, 32.9), ('USC00516128', 147.81000000000006, 21.3331, -157.8025, 152.4), ('USC00513117', 48.510000000000026, 21.4234, -157.8015, 14.6), ('USC00514830', 33.239999999999995, 21.5213, -157.8374, 7.0), ('USC00517948', 4.59, 21.3934, -157.9751, 11.9)]

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# Use the start and end date to create a range of dates
# Stip off the year and save a list of %m-%d strings

import datetime
date1 = '2016-08-23'
date2 = '2017-08-23'
start = datetime.datetime.strptime(date1, '%Y-%m-%d')
end = datetime.datetime.strptime(date2, '%Y-%m-%d')
step = datetime.timedelta(days=1)
dates = []
while start <= end:
    string_date = start.date().strftime("%m-%d")
    dates.append(string_date)
    print(string_date)
    start += step
# Out:
# 08-23
# 08-24
# 08-25
# 08-26
# 08-27
# 08-28
# 08-29
# 08-30
# 08-31
# 09-01
# 09-02
# 09-03
# 09-04
# 09-05
# 09-06
# 09-07
# 09-08
# 09-09
# 09-10
# 09-11
# 09-12
# 09-13
# 09-14
# 09-15
# 09-16
# 09-17
# 09-18
# 09-19
# 09-20
# 09-21
# 09-22
# 09-23
# 09-24
# 09-25
# 09-26
# 09-27
# 09-28
# 09-29
# 09-30
# 10-01
# 10-02
# 10-03
# 10-04
# 10-05
# 10-06
# 10-07
# 10-08
# 10-09
# 10-10
# 10-11
# 10-12
# 10-13
# 10-14
# 10-15
# 10-16
# 10-17
# 10-18
# 10-19
# 10-20
# 10-21
# 10-22
# 10-23
# 10-24
# 10-25
# 10-26
# 10-27
# 10-28
# 10-29
# 10-30
# 10-31
# 11-01
# 11-02
# 11-03
# 11-04
# 11-05
# 11-06
# 11-07
# 11-08
# 11-09
# 11-10
# 11-11
# 11-12
# 11-13
# 11-14
# 11-15
# 11-16
# 11-17
# 11-18
# 11-19
# 11-20
# 11-21
# 11-22
# 11-23
# 11-24
# 11-25
# 11-26
# 11-27
# 11-28
# 11-29
# 11-30
# 12-01
# 12-02
# 12-03
# 12-04
# 12-05
# 12-06
# 12-07
# 12-08
# 12-09
# 12-10
# 12-11
# 12-12
# 12-13
# 12-14
# 12-15
# 12-16
# 12-17
# 12-18
# 12-19
# 12-20
# 12-21
# 12-22
# 12-23
# 12-24
# 12-25
# ...

# %%
dates
# Out:
# ['08-23',
#  '08-24',
#  '08-25',
#  '08-26',
#  '08-27',
#  '08-28',
#  '08-29',
#  '08-30',
#  '08-31',
#  '09-01',
#  '09-02',
#  '09-03',
#  '09-04',
#  '09-05',
#  '09-06',
#  '09-07',
#  '09-08',
#  '09-09',
#  '09-10',
#  '09-11',
#  '09-12',
#  '09-13',
#  '09-14',
#  '09-15',
#  '09-16',
#  '09-17',
#  '09-18',
#  '09-19',
#  '09-20',
#  '09-21',
#  '09-22',
#  '09-23',
#  '09-24',
#  '09-25',
#  '09-26',
#  '09-27',
#  '09-28',
#  '09-29',
#  '09-30',
#  '10-01',
#  '10-02',
#  '10-03',
#  '10-04',
#  '10-05',
#  '10-06',
#  '10-07',
#  '10-08',
#  '10-09',
#  '10-10',
#  '10-11',
#  '10-12',
#  '10-13',
#  '10-14',
#  '10-15',
#  '10-16',
#  '10-17',
#  '10-18',
#  '10-19',
#  '10-20',
#  '10-21',
#  '10-22',
#  '10-23',
#  '10-24',
#  '10-25',
#  '10-26',
#  '10-27',
#  '10-28',
#  '10-29',
#  '10-30',
#  '10-31',
#  '11-01',
#  '11-02',
#  '11-03',
#  '11-04',
#  '11-05',
#  '11-06',
#  '11-07',
#  '11-08',
#  '11-09',
#  '11-10',
#  '11-11',
#  '11-12',
#  '11-13',
# ...

# %%
# Loop through the list of %m-%d strings and calculate the normals for each date

tmin = []
tavg = []
tmax = []
for d in dates:
    i = daily_normals(d)
    
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    dm =  session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == d).all()
    
    
    for t in dm:
        (Tmin, Tavg, Tmax) = t
        print(Tmin, Tavg, Tmax)
        tmin.append(Tmin)
        tavg.append(Tavg)
        tmax.append(Tmax)
# Out:
# 67.0 76.6923076923077 87.0
# 70.0 75.96153846153847 84.0
# 69.0 76.96078431372548 82.0
# 71.0 76.56862745098039 84.0
# 68.0 76.28301886792453 84.0
# 67.0 76.73469387755102 86.0
# 70.0 76.23529411764706 85.0
# 68.0 76.41666666666667 84.0
# 67.0 76.84 85.0
# 69.0 77.0 82.0
# 67.0 76.66666666666667 83.0
# 69.0 76.13725490196079 83.0
# 68.0 76.27083333333333 84.0
# 66.0 75.91489361702128 84.0
# 66.0 74.91111111111111 81.0
# 64.0 75.18 82.0
# 66.0 76.22222222222223 83.0
# 68.0 76.36538461538461 84.0
# 67.0 76.61224489795919 85.0
# 70.0 76.69565217391305 83.0
# 68.0 75.89795918367346 85.0
# 68.0 75.875 82.0
# 69.0 75.98076923076923 85.0
# 67.0 76.14 81.0
# 70.0 77.40384615384616 86.0
# 68.0 76.57692307692308 83.0
# 67.0 75.85106382978724 84.0
# 68.0 76.34693877551021 87.0
# 69.0 76.14583333333333 83.0
# 67.0 76.44897959183673 84.0
# 69.0 76.37254901960785 84.0
# 67.0 75.82692307692308 83.0
# 69.0 77.02 85.0
# 69.0 76.14893617021276 83.0
# 66.0 75.64 85.0
# 68.0 75.64 83.0
# ...

# %%
tmin_df= pd.DataFrame(tmin, columns=["Temp_min"])
tmin_df.head()
# Out:
#    Temp_min
# 0      67.0
# 1      70.0
# 2      69.0
# 3      71.0
# 4      68.0

# %%
tavg_df= pd.DataFrame(tavg, columns=["Temp_avg"])
tavg_df.head()
# Out:
#     Temp_avg
# 0  76.692308
# 1  75.961538
# 2  76.960784
# 3  76.568627
# 4  76.283019

# %%
tmax_df= pd.DataFrame(tmax, columns=["Temp_max"])
tmax_df.head()
# Out:
#    Temp_max
# 0      87.0
# 1      84.0
# 2      82.0
# 3      84.0
# 4      84.0

# %%
dates_df= pd.DataFrame(dates, columns=["Date mm-dd"])
dates_df.head()
# Out:
#   Date mm-dd
# 0      08-23
# 1      08-24
# 2      08-25
# 3      08-26
# 4      08-27

# %%
daily_normal_df =pd.concat([dates_df, tmin_df, tavg_df, tmax_df], axis=1)
daily_normal_df.set_index('Date mm-dd', inplace=True)
daily_normal_df.head()
# Out:
#             Temp_min   Temp_avg  Temp_max
# Date mm-dd
# 08-23           67.0  76.692308      87.0
# 08-24           70.0  75.961538      84.0
# 08-25           69.0  76.960784      82.0
# 08-26           71.0  76.568627      84.0
# 08-27           68.0  76.283019      84.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
daily_normal_df[30:40].plot.area(stacked=False)
